# %% [markdown]
# ## Computer Vision

# %% [markdown]
# - It's a field of Artificial Intelligence that used to preprocess image and video to trained ML model. It's a field that works on images and video to trained or classified different images and videos.
# - Important Library
#   1. OpenCV
#   2. CNN
#   3. dlib
#   4. google vision
#   5. mediapipe

# %%
import cv2

# %%
img1=cv2.imread('img.jpg',1)
img=cv2.resize(img1,(600,600))
cv2.imshow('Img',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img1=cv2.imread('img.jpg',cv2.IMREAD_COLOR)
img=cv2.resize(img1,(600,600))
cv2.imshow('Img',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print(type(img))
print(img.ndim)
# Out:
# <class 'numpy.ndarray'>
# 3

# %%
img1=cv2.imread('img.jpg',cv2.IMREAD_GRAYSCALE)
img=cv2.resize(img1,(600,600))
cv2.imshow('Img',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print(type(img))
print(img.ndim)
print(cv2.IMREAD_COLOR)
print(cv2.IMREAD_GRAYSCALE)
# Out:
# <class 'numpy.ndarray'>
# 2
# 1
# 0

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img,cmap='winter')
plt.show()

# %%
plt.imshow(img,cmap='gray')
plt.show()

# %%
plt.imshow(img,cmap='brg')
plt.show()
