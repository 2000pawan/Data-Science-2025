# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler,MaxAbsScaler,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## Feature Scaling with MinMax Scaler

# %%
df=pd.read_csv("G:/dataset/classification/fruits.csv")
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.33,random_state=22)
sc=MinMaxScaler()
X_train_new=sc.fit_transform(X_train)
X_test_new=sc.transform(X_test)
model=KNeighborsClassifier()
model.fit(X_train_new,y_train)
pred_train=model.predict(X_train_new)
pred_test=model.predict(X_test_new)
print("Accuracy Score of Training:- ",accuracy_score(y_train,pred_train))
print("Accuracy Score of Testing:- ",accuracy_score(y_test,pred_test))
# Out:
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.875

# %% [markdown]
# ## Feature Scaling with MaxAbs Scaler.

# %%
df=pd.read_csv("G:/dataset/classification/fruits.csv")
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.33,random_state=22)
sc=MaxAbsScaler()
X_train_new=sc.fit_transform(X_train)
X_test_new=sc.transform(X_test)
model=KNeighborsClassifier()
model.fit(X_train_new,y_train)
pred_train=model.predict(X_train_new)
pred_test=model.predict(X_test_new)
print("Accuracy Score of Training:- ",accuracy_score(y_train,pred_train))
print("Accuracy Score of Testing:- ",accuracy_score(y_test,pred_test))
# Out:
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.875

# %% [markdown]
# ## Feature Scaling with Standard Scaler.

# %%
df=pd.read_csv("G:/dataset/classification/fruits.csv")
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.33,random_state=22)
sc=StandardScaler()
X_train_new=sc.fit_transform(X_train)
X_test_new=sc.transform(X_test)
model=KNeighborsClassifier()
model.fit(X_train_new,y_train)
pred_train=model.predict(X_train_new)
pred_test=model.predict(X_test_new)
print("Accuracy Score of Training:- ",accuracy_score(y_train,pred_train))
print("Accuracy Score of Testing:- ",accuracy_score(y_test,pred_test))
# Out:
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.875

# %% [markdown]
# ## Parameter Tuning/Hyperparameter Tuning

# %% [markdown]
# ## Standard Scaler Hyperparameter Tuning

# %%
df=pd.read_csv("G:/dataset/classification/fruits.csv")
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=22)
sc=StandardScaler()
X_train_new=sc.fit_transform(X_train)
X_test_new=sc.transform(X_test)
dist=['minkowski','euclidean','manhattan']
for i in range(1,8):
    print(f"---Neighbors:- {i} -------")
    for j in dist:
        print(f"------Metrics:- {j}----------")
        model=KNeighborsClassifier(n_neighbors=i,metric=j)
        model.fit(X_train_new,y_train)
        pred_train=model.predict(X_train_new)
        pred_test=model.predict(X_test_new)
        print("Accuracy Score of Training:- ",accuracy_score(y_train,pred_train))
        print("Accuracy Score of Testing:- ",accuracy_score(y_test,pred_test))
        print("----------------------------------------------")
    print("\n\n----------------------------------------------")
# Out:
# ---Neighbors:- 1 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 2 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 3 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 4 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 5 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 6 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 7 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------

# %% [markdown]
# ## MinMax Scaler Scaler Hyperparameter Tuning

# %%
df=pd.read_csv("G:/dataset/classification/fruits.csv")
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25,random_state=22)
sc=MinMaxScaler()
X_train_new=sc.fit_transform(X_train)
X_test_new=sc.transform(X_test)
dist=['minkowski','euclidean','manhattan']
for i in range(1,8):
    print(f"---Neighbors:- {i} -------")
    for j in dist:
        print(f"------Metrics:- {j}----------")
        model=KNeighborsClassifier(n_neighbors=i,metric=j)
        model.fit(X_train_new,y_train)
        pred_train=model.predict(X_train_new)
        pred_test=model.predict(X_test_new)
        print("Accuracy Score of Training:- ",accuracy_score(y_train,pred_train))
        print("Accuracy Score of Testing:- ",accuracy_score(y_test,pred_test))
        print("----------------------------------------------")
    print("\n\n----------------------------------------------")
# Out:
# ---Neighbors:- 1 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 2 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 3 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 4 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 5 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 6 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 7 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------

# %% [markdown]
# ## MaxAbs Scaler Hyperparameter Tuning

# %%
df=pd.read_csv("G:/dataset/classification/fruits.csv")
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25,random_state=22)
sc=MaxAbsScaler()
X_train_new=sc.fit_transform(X_train)
X_test_new=sc.transform(X_test)
dist=['minkowski','euclidean','manhattan']
for i in range(1,8):
    print(f"---Neighbors:- {i} -------")
    for j in dist:
        print(f"------Metrics:- {j}----------")
        model=KNeighborsClassifier(n_neighbors=i,metric=j)
        model.fit(X_train_new,y_train)
        pred_train=model.predict(X_train_new)
        pred_test=model.predict(X_test_new)
        print("Accuracy Score of Training:- ",accuracy_score(y_train,pred_train))
        print("Accuracy Score of Testing:- ",accuracy_score(y_test,pred_test))
        print("----------------------------------------------")
    print("\n\n----------------------------------------------")
# Out:
# ---Neighbors:- 1 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 2 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 3 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 4 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 5 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  1.0
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 6 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
# ---Neighbors:- 7 -------
# ------Metrics:- minkowski----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- euclidean----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
# ------Metrics:- manhattan----------
# Accuracy Score of Training:-  0.9375
# Accuracy Score of Testing:-  0.8333333333333334
# ----------------------------------------------
#
#
# ----------------------------------------------
